# %% [markdown]
# # *Abalone*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv("C:/Users/user/Downloads/abalone/abalone.csv", header=None)
df
# Out:
#       0      1      2      3       4       5       6       7   8
# 0     M  0.455  0.365  0.095  0.5140  0.2245  0.1010  0.1500  15
# 1     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 2     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 3     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 4     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4172  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4173  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4174  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4175  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4176  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4177 rows x 9 columns]

# %%
df.columns = ['Sex', 'Length', 'Diam', 'Height', 'Whole' , 'Shucked', 'Viscera', 'Shell', 'Rings']

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diam', 'Height', 'Whole', 'Shucked', 'Viscera',
#        'Shell', 'Rings'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Sex        0
# Length     0
# Diam       0
# Height     0
# Whole      0
# Shucked    0
# Viscera    0
# Shell      0
# Rings      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Sex'] = le.fit_transform(df['Sex'])

# %%
df.describe()
# Out:
#                Sex       Length         Diam       Height        Whole  \
# count  4177.000000  4177.000000  4177.000000  4177.000000  4177.000000
# mean      1.052909     0.523992     0.407881     0.139516     0.828742
# std       0.822240     0.120093     0.099240     0.041827     0.490389
# min       0.000000     0.075000     0.055000     0.000000     0.002000
# 25%       0.000000     0.450000     0.350000     0.115000     0.441500
# 50%       1.000000     0.545000     0.425000     0.140000     0.799500
# 75%       2.000000     0.615000     0.480000     0.165000     1.153000
# max       2.000000     0.815000     0.650000     1.130000     2.825500
#
#            Shucked      Viscera        Shell        Rings
# count  4177.000000  4177.000000  4177.000000  4177.000000
# mean      0.359367     0.180594     0.238831     9.933684
# std       0.221963     0.109614     0.139203     3.224169
# min       0.001000     0.000500     0.001500     1.000000
# ...

# %%
df.mode()
# Out:
#    Sex  Length  Diam  Height   Whole  Shucked  Viscera  Shell  Rings
# 0  2.0   0.550  0.45    0.15  0.2225    0.175   0.1715  0.275    9.0
# 1  NaN   0.625   NaN     NaN     NaN      NaN      NaN    NaN    NaN

# %%
df
# Out:
#       Sex  Length   Diam  Height   Whole  Shucked  Viscera   Shell  Rings
# 0       2   0.455  0.365   0.095  0.5140   0.2245   0.1010  0.1500     15
# 1       2   0.350  0.265   0.090  0.2255   0.0995   0.0485  0.0700      7
# 2       0   0.530  0.420   0.135  0.6770   0.2565   0.1415  0.2100      9
# 3       2   0.440  0.365   0.125  0.5160   0.2155   0.1140  0.1550     10
# 4       1   0.330  0.255   0.080  0.2050   0.0895   0.0395  0.0550      7
# ...   ...     ...    ...     ...     ...      ...      ...     ...    ...
# 4172    0   0.565  0.450   0.165  0.8870   0.3700   0.2390  0.2490     11
# 4173    2   0.590  0.440   0.135  0.9660   0.4390   0.2145  0.2605     10
# 4174    2   0.600  0.475   0.205  1.1760   0.5255   0.2875  0.3080      9
# 4175    0   0.625  0.485   0.150  1.0945   0.5310   0.2610  0.2960     10
# 4176    2   0.710  0.555   0.195  1.9485   0.9455   0.3765  0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.hist(figsize=(20,10), grid=True, bins=30)
# Out:
# array([[<Axes: title={'center': 'Sex'}>,
#         <Axes: title={'center': 'Length'}>,
#         <Axes: title={'center': 'Diam'}>],
#        [<Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Whole'}>,
#         <Axes: title={'center': 'Shucked'}>],
#        [<Axes: title={'center': 'Viscera'}>,
#         <Axes: title={'center': 'Shell'}>,
#         <Axes: title={'center': 'Rings'}>]], dtype=object)

# %%
sns.countplot(x='Sex', data=df, palette="Set3")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
plt.figure(figsize=(20, 7))
sns.swarmplot(x = 'Sex', y = 'Rings', data=df, hue = 'Sex')
sns.violinplot(x = 'Sex', y = 'Rings', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Rings'>

# %%
num_features = df.select_dtypes(include=[np.number]).columns
sns.pairplot(df[num_features])

# %%
X = df.drop('Rings', axis=1)


y = df['Rings']

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression


model = LinearRegression()

model.fit(X_train, y_train)


from sklearn.metrics import mean_squared_error


ly_preds = model.predict(X_test)

mse = np.sqrt(mean_squared_error(ly_preds, y_test))

print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 2.1955229234843956

# %% [markdown]
# ### 이상치 제거

# %%
# Shell before

plt.scatter(x = df['Shell'], y = df['Rings'])
plt.grid(True)

# %%
df.drop(df[df['Shell'] > 0.8].index, inplace=True)
df.drop(df[df['Rings'] > 25].index, inplace=True)

# %%
# shell after

plt.scatter(x = df['Shell'], y = df['Rings'])
plt.grid(True)

# %%
# Viscera before

plt.scatter(x = df['Viscera'], y = df['Rings'])
plt.grid(True)

# %%
df.drop(df[df['Viscera'] > 0.58].index, inplace=True)
df.drop(df[df['Rings'] > 23].index, inplace=True)

# %%
# Viscera after

plt.scatter(x = df['Viscera'], y = df['Rings'])
plt.grid(True)

# %%
# Shucked before

plt.scatter(x = df['Shucked'], y = df['Rings'])
plt.grid(True)

# %%
df.drop(df[df['Shucked'] > 1.2].index, inplace=True)
df.drop(df[df['Rings'] > 24].index, inplace=True)

# %%
# Shucked after

plt.scatter(x = df['Shucked'], y = df['Rings'])
plt.grid(True)

# %%
# Whole before

plt.scatter(x = df['Whole'], y = df['Rings'])
plt.grid(True)

# %%
df.drop(df[df['Whole'] > 2.4].index, inplace=True)
df.drop(df[df['Rings'] > 24].index, inplace=True)

# %%
# Whole after

plt.scatter(x = df['Whole'], y = df['Rings'])
plt.grid(True)

# %%
# Diam before

plt.scatter(x = df['Diam'], y = df['Rings'])
plt.grid(True)

# %%
df.drop(df[df['Diam'] > 0.6].index, inplace=True)
df.drop(df[df['Rings'] > 24].index, inplace=True)

# %%
# Diam after

plt.scatter(x = df['Diam'], y = df['Rings'])
plt.grid(True)

# %%
# Height before

plt.scatter(x = df['Height'], y = df['Rings'])
plt.grid(True)

# %%
df.drop(df[df['Height'] > 0.3].index, inplace=True)
df.drop(df[df['Rings'] > 24].index, inplace=True)

# %%
# Height after

plt.scatter(x = df['Height'], y = df['Rings'])
plt.grid(True)

# %%
# Length before

plt.scatter(x = df['Length'], y = df['Rings'])
plt.grid(True)

# %%
df.drop(df[df['Length'] > 0.7].index, inplace=True)
df.drop(df[df['Rings'] > 24].index, inplace=True)

# %%
# Length after

plt.scatter(x = df['Length'], y = df['Rings'])
plt.grid(True)

# %%
X = df.drop('Rings', axis=1)


y = df['Rings']

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression


model = LinearRegression()

model.fit(X_train, y_train)


from sklearn.metrics import mean_squared_error


ly_preds = model.predict(X_test)

mse = np.sqrt(mean_squared_error(ly_preds, y_test))

print('평균제곱근오차', mse)
# Out:
# 평균제곱근오차 2.145192638010025

# %% [markdown]
# ### 이상치 제거 전 MSE : 2.19...
# ### 이상치 제거 후 MSE : 2.14...
